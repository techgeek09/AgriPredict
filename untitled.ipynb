# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/upflairs-pvt-ltd/3rd_july_datascience/master/farmer_guider/farmer.csv")
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
group=df.groupby('label')

# %%
group[['N']].mean() #N=Nitrogen
# Out:
#                   N
# label
# apple         20.80
# banana       100.23
# blackgram     40.02
# chickpea      40.09
# coconut       21.98
# coffee       101.20
# cotton       117.77
# grapes        23.18
# jute          78.40
# kidneybeans   20.75
# lentil        18.77
# maize         77.76
# mango         20.07
# mothbeans     21.44
# mungbean      20.99
# muskmelon    100.32
# orange        19.58
# papaya        49.88
# pigeonpeas    20.73
# pomegranate   18.87
# rice          79.89
# watermelon    99.42

# %%
group[['temperature']].mean()
# Out:
#              temperature
# label
# apple          22.630942
# banana         27.376798
# blackgram      29.973340
# chickpea       18.872847
# coconut        27.409892
# coffee         25.540477
# cotton         23.988958
# grapes         23.849575
# jute           24.958376
# kidneybeans    20.115085
# lentil         24.509052
# maize          22.389204
# mango          31.208770
# mothbeans      28.194920
# mungbean       28.525775
# muskmelon      28.663066
# orange         22.765725
# papaya         33.723859
# pigeonpeas     27.741762
# pomegranate    21.837842
# rice           23.689332
# watermelon     25.591767

# %%
## PROBLEM STATEMENT- EK Crop ke requirements ke basis pei hum aur crops recommend karna hai so that farmers ko variety mile crops grow karne ki
## CLUSTERING ANALYSIS - Calculating the similarities and differences

# %%
# Euclidian distance- smallest possible distance

# %%
# Calculating mean, min, and max all together
result = group[['temperature']].agg(['mean', 'min', 'max'])
result
# Out:
#             temperature
#                    mean        min        max
# label
# apple         22.630942  21.036527  23.996862
# banana        27.376798  25.010185  29.908885
# blackgram     29.973340  25.097374  34.946616
# chickpea      18.872847  17.024985  20.995022
# coconut       27.409892  25.008724  29.869083
# coffee        25.540477  23.059519  27.923744
# cotton        23.988958  22.000851  25.992374
# grapes        23.849575   8.825675  41.948657
# jute          24.958376  23.094338  26.985822
# kidneybeans   20.115085  15.330426  24.923601
# lentil        24.509052  18.064861  29.944139
# maize         22.389204  18.041855  26.549864
# mango         31.208770  27.003155  35.990097
# mothbeans     28.194920  24.018254  31.999286
# mungbean      28.525775  27.014704  29.914544
# muskmelon     28.663066  27.024151  29.943492
# orange        22.765725  10.010813  34.906653
# papaya        33.723859  23.012402  43.675493
# pigeonpeas    27.741762  18.319104  36.977944
# ...

# %%
min_temperature = group['temperature'].min()
min_temperature.plot.bar(color='blue')

plt.xlabel('Label')
plt.ylabel('Avg Temperature')
plt.title('Avg Temperature by Label')

plt.show()

# %%
plt.pie()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.pie()
#
# TypeError: pie() missing 1 required positional argument: 'x'

# %%
x= df.drop('label',axis='columns')
x.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
x.isnull().sum
# Out:
# <bound method DataFrame.sum of           N      P      K  temperature  humidity     ph  rainfall
# 0     False  False  False        False     False  False     False
# 1     False  False  False        False     False  False     False
# 2     False  False  False        False     False  False     False
# 3     False  False  False        False     False  False     False
# 4     False  False  False        False     False  False     False
# ...     ...    ...    ...          ...       ...    ...       ...
# 2195  False  False  False        False     False  False     False
# 2196  False  False  False        False     False  False     False
# 2197  False  False  False        False     False  False     False
# 2198  False  False  False        False     False  False     False
# 2199  False  False  False        False     False  False     False
#
# [2200 rows x 7 columns]>

# %%
df.info
# Out:
# <bound method DataFrame.info of         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]>

# %%
x.duplicated().sum() #duplicates free
# Out:
# np.int64(0)

# %%
x #All numerical values, no categorical values
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
x.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# dtype: object

# %%
sns.kdeplot(x['temperature'])
# Out:
# <Axes: xlabel='temperature', ylabel='Density'>

# %%
x.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
##Data Transformation
from sklearn.preprocessing import StandardScaler

# %%
std_scaler=StandardScaler()
x_transformed = std_scaler.fit_transform(x)

# %%
x_transformed.shape
# Out:
# (2200, 7)

# %%
x.shape
# Out:
# (2200, 7)

# %%
pd.DataFrame(x_transformed)
# Out:
#              0         1         2         3         4         5         6
# 0     1.068797 -0.344551 -0.101688 -0.935587  0.472666  0.043302  1.810361
# 1     0.933329  0.140616 -0.141185 -0.759646  0.397051  0.734873  2.242058
# 2     0.255986  0.049647 -0.081939 -0.515898  0.486954  1.771510  2.921066
# 3     0.635298 -0.556811 -0.160933  0.172807  0.389805  0.660308  2.537048
# 4     0.743673 -0.344551 -0.121436 -1.083647  0.454792  1.497868  2.898373
# ...        ...       ...       ...       ...       ...       ...       ...
# 2195  1.529390 -0.587134 -0.318922  0.228814 -0.227709  0.401395  1.352437
# 2196  1.312641 -1.163269 -0.417666  0.355720 -0.666947 -0.494413  0.445183
# 2197  1.827421 -0.617457 -0.358420 -0.293218 -0.191235 -0.138120  1.271418
# 2198  1.800327 -0.647780 -0.279425  0.129612 -0.869518  0.373904  0.431545
# 2199  1.448109 -1.072300 -0.358420 -0.397667 -0.498020  0.401096  0.682005
#
# [2200 rows x 7 columns]

# %%
pd.DataFrame(x_transformed)[3] #Temperature column
# Out:
# 0      -0.935587
# 1      -0.759646
# 2      -0.515898
# 3       0.172807
# 4      -1.083647
#           ...
# 2195    0.228814
# 2196    0.355720
# 2197   -0.293218
# 2198    0.129612
# 2199   -0.397667
# Name: 3, Length: 2200, dtype: float64

# %%
x.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
sns.kdeplot(pd.DataFrame(x_transformed)[3]) #After scaling down the code is still the same
# Out:
# <Axes: xlabel='3', ylabel='Density'>

# %%
###ready to train the algorithm
from sklearn.cluster import KMeans

# %%
kmeans_obj=KMeans()

# %%
labels= kmeans_obj.fit_predict(x_transformed) #training algorithm

# %%
set(labels)
# Out:
# {np.int32(0),
#  np.int32(1),
#  np.int32(2),
#  np.int32(3),
#  np.int32(4),
#  np.int32(5),
#  np.int32(6),
#  np.int32(7)}

# %%
labels
# Out:
# array([4, 4, 4, ..., 4, 1, 4], dtype=int32)

# %%
labels.shape
# Out:
# (2200,)

# %%
x_transformed.shape
# Out:
# (2200, 7)

# %%
df['cluster_no'] =labels

# %%
df.head(40)
# Out:
#      N   P   K  temperature   humidity        ph    rainfall label  cluster_no
# 0   90  42  43    20.879744  82.002744  6.502985  202.935536  rice           4
# 1   85  58  41    21.770462  80.319644  7.038096  226.655537  rice           4
# 2   60  55  44    23.004459  82.320763  7.840207  263.964248  rice           4
# 3   74  35  40    26.491096  80.158363  6.980401  242.864034  rice           4
# 4   78  42  42    20.130175  81.604873  7.628473  262.717340  rice           4
# 5   69  37  42    23.058049  83.370118  7.073454  251.055000  rice           4
# 6   69  55  38    22.708838  82.639414  5.700806  271.324860  rice           4
# 7   94  53  40    20.277744  82.894086  5.718627  241.974195  rice           4
# 8   89  54  38    24.515881  83.535216  6.685346  230.446236  rice           4
# 9   68  58  38    23.223974  83.033227  6.336254  221.209196  rice           4
# 10  91  53  40    26.527235  81.417538  5.386168  264.614870  rice           4
# ...

# %%
df[df['cluster_no'] == 4]['label'].unique()
# Out:
# array(['rice', 'pigeonpeas', 'papaya', 'jute', 'coffee'], dtype=object)

# %%
import os,joblib
os.makedirs('models',exist_ok=True)
joblib.dump(std_scaler,'./models/std_scaler.lb')
joblib.dump(kmeans_obj,'./models/kmeans_model.lb')
# Out:
# ['./models/kmeans_model.lb']

# %%
df[['label','cluster_no']].to_csv('./models/filter_crops.csv',index=False)
